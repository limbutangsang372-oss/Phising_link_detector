# %% [markdown]
# # Phising link detector Notebook
#
# This notebook demonstrates the project workflow: load URL data, extract features, train models, and compare results.

# %%
import sys
sys.path.append('../src')

import pandas as pd
from feature_extraction import transform_urls_to_features

df = pd.read_csv('../data/sample_urls.csv')
df.head()

# %%
features = pd.DataFrame(transform_urls_to_features(df['url']))
features['label'] = df['label']
features.head()

# %% [markdown]
# Run `python src/train_models.py` from the project folder to generate the full model comparison outputs.
